# %% [markdown]
# **Ejercicio (A)**

# %%
def contador_palabras(arr, pos_i, pos_f):
  arr=arreglo.split()
  pos_f=len(arr)
  print(pos_f)

# %%
arreglo=input("Ingrese texto: ")
longitud_del_arreglo=int(input("Ingrese pos final: "))

contador_palabras(arreglo, 0, longitud_del_arreglo)
# Out:
# Ingrese texto: hola, como te fue en el dia de hoy?
# Ingrese pos final: 5
# 9

# %% [markdown]
# **Ejercicio (B)**

# %%
texto=input("Ingrese texto: ")

def tot_palabras_por_linea(txt):
  txt=texto.split()
  n=0
  for i in txt:
    num_palabras=len(txt)
    i+=1
    if i=="\n":
      i=n
      i=0
    elif i!="\n":
      i+=1
  print(n)
      

#no me sale :( miss podría publicar la respuesta? Porfavorcito?
# Out:
# Ingrese texto: hola \n como \n estas 5

# %%
tot_palabras_por_linea(texto)
# Out:
# 3

# %% [markdown]
# **Ejercicio (C)**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
def tot_palabras_archivo(fileref):
   with open(fileref) as f_obj:
     texto=f_obj.read()
     
     #----------------
     palabras=texto.split()
     num_palabras=len(palabras)
     print(num_palabras)

# %%
fileref="/Loremtext.txt"
tot_palabras_archivo(fileref)
# Out:
# 5000
